# %%
import os
import re

import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

import PyPDF2
import docx2txt
from PyPDF2 import PdfFileReader

from collections import defaultdict
from pdf2image import convert_from_path
from pptx import Presentation

# %%
def as_text_file_path(name):
    text_file_dir = 'C:/temp/temp/text'
    file_name = re.sub('[.\\ :-]', '_', name).replace('\\', '_')
    return os.path.join(text_file_dir, file_name)
# Out:
# <function __main__.as_text_file_path(name)>

# %%
root_dir = r'C:\temp\temp\zip\82 Johtoryhmän esityslista\Johtoryhmä - Steering committee'
# os.listdir(r'C:\temp\temp\zip\82 Johtoryhmän esityslista\Johtoryhmä - Steering committee')

extension_count = defaultdict(int)
extension_files = defaultdict(list)
names = {}

for root, dirs, files in os.walk(root_dir, topdown=False):
    for name in files:
        file_path = os.path.join(root, name)
        text_file_name = as_text_file_path(file_path)
        names[text_file_name] = name
        extension = name.split('.')[-1]
        extension_count[extension] += 1
        extension_files[extension] += [file_path]
extension_count
# extension_files
# Out:
# defaultdict(int, {'pdf': 82, 'pptx': 42, 'xlsx': 8, 'docx': 38, 'PPTX': 1})

# %%
names
# Out:
# {'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_05_29_Emma_Maija_johtoryhmä_2017_05_29_esityslista_pdf': 'Emma-Maija johtoryhmä 2017-05-29 esityslista.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_05_29_Emma_Maija_johtoryhmä_2017_05_29_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-05-29 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_05_29_Emma_Maija_johtoryhmä_2017_05_29_tilanneraportti_pdf': 'Emma-Maija johtoryhmä 2017-05-29 tilanneraportti.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_08_22_Emma_Maija_johtoryhmä_2017_08_22_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-08-22 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_08_22_Emma_Maija_johtoryhmän_kokous_2017_08_22_pdf': 'Emma-Maija johtoryhmän kokous 2017-08-22.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_09_12_Emma_Maija_johtoryhmä_2017_08_22_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-08-22 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_09_12_Emma_Maija_johtoryhmä_2017_09_12_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-09-12 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_09_12_Emma_Maija_johtoryhmän_kokous_2017_09_12_pdf': 'Emma-Maija johtoryhmän kokous 2017-09-12.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_10_11_Emma_Maija_johtoryhmä_2017_08_22_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-08-22 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_10_11_Emma_Maija_johtoryhmä_2017_09_12_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-09-12 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_10_11_Emma_Maija_johtoryhmä_2017_10_11_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-10-11 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_10_11_Emma_Maija_johtoryhmän_kokous_2017_10_11_pdf': 'Emma-Maija johtoryhmän kokous 2017-10-11.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_10_11_Lliite_4_2_Riskilista_v_1_1_2017_10_11_pdf': 'Lliite 4.2 Riskilista v 1.1 2017-10-11.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_11_07_Emma_Maija_johtoryhmä_2017_09_12_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-09-12 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_11_07_Emma_Maija_johtoryhmä_2017_10_11_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-10-11 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_11_07_Emma_Maija_johtoryhmä_2017_11_07_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-11-07 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_11_07_Emma_Maija_johtoryhmän_kokous_2017_11_07_pptx': 'Emma-Maija johtoryhmän kokous 2017-11-07.pptx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_11_07_Lliite_4_2_Riskilista_v_1_1_2017_11_07_xlsx': 'Lliite 4.2 Riskilista v 1.1 2017-11-07.xlsx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_11_07_Muutosloki_xlsx': 'Muutosloki.xlsx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_12_12_Emma_Maija_johtoryhmä_2017_10_11_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-10-11 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_12_12_Emma_Maija_johtoryhmä_2017_11_07_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-11-07 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017_12_12_Emma_Maija_johtoryhmä_2017_12_12_pöytäkirja_pdf': 'Emma-Maija johtoryhmä 2017-12-12 pöytäkirja.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2017
docx': 'Emma-Maija johtoryhmä pöytäkirja 2020-09-22.docx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_09_22_Emma_Maija_johtoryhmäraportti___22_9_2020_pptx': 'Emma-Maija johtoryhmäraportti - 22.9.2020.pptx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_09_22_Toimittajan_kokonaisaikataulu_11_9_2020_pdf': 'Toimittajan kokonaisaikataulu 11.9.2020.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_10_19_Emma_Maija_Hinnoittelun_näkemyserot___draft_pptx': 'Emma-Maija Hinnoittelun näkemyserot - draft.pptx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_10_19_Emma_Maija_johtoryhmä_pöytäkirja_2020_10_19_docx': 'Emma-Maija johtoryhmä pöytäkirja 2020-10-19.docx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_10_19_Emma_Maija_johtoryhmäraportti___19_10_2020_pptx': 'Emma-Maija johtoryhmäraportti - 19.10.2020.pptx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_10_19_Toimittajan_kokonaisaikataulu_9_10_2020_pdf': 'Toimittajan kokonaisaikataulu 9.10.2020.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_11_11_Emma_Maija_johtoryhmä_pöytäkirja_2020_11_11_docx': 'Emma-Maija johtoryhmä pöytäkirja 2020-11-11.docx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_11_11_Emma_Maija_johtoryhmäraportti___11_11_2020_pptx': 'Emma-Maija johtoryhmäraportti - 11.11.2020.pptx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_11_11_Emma_Maija_johtoryhmäraportti___12_11_2020_pptx': 'Emma-Maija johtoryhmäraportti - 12.11.2020.pptx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_11_24_Emma_Maija_johtoryhmä_pöytäkirja_2020_11_24_docx': 'Emma-Maija johtoryhmä pöytäkirja 2020-11-24.docx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_11_24_Emma_Maija_johtoryhmäraportti___24_11_2020_draft_pptx': 'Emma-Maija johtoryhmäraportti - 24.11.2020 draft.pptx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_11_24_Toimittajan_kokonaisaikataulu_1_11_2020_pdf': 'Toimittajan kokonaisaikataulu 1.11.2020.pdf',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_2020_12_15_Emma_Maija_johtoryhmäraportti___15_12_2020_draft_pptx': 'Emma-Maija johtoryhmäraportti - 15.12.2020 draft.pptx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_Emma_Maija_johtoryhmä_arkistoidut_sovitut_toimenpiteet_ja_päätökset_docx': 'Emma-Maija johtoryhmä arkistoidut sovitut toimenpiteet ja päätökset.docx',
#  'C:/temp/temp/text\\C__temp_temp_zip_82_Johtoryhmän_esityslista_Johtoryhmä___Steering_committee_Liite_4_2_Riskilista_xlsx': 'Liite 4.2 Riskilista.xlsx'}

# %%
# !md c:\temp\temp\text

# %%
file_path = 'C:\\temp\\temp\\zip\\82 Johtoryhmän esityslista\\Johtoryhmä - Steering committee\\2018-06-18\\Emma-Maija johtoryhmä 2018-06-11.pdf'

def text_from_pdf_text(file_path):
    ret = ''
    with open(file_path, 'rb') as f:
        text = ''
        pdf = PdfFileReader(f)
        for page_no in range(pdf.getNumPages()):
            page = pdf.getPage(page_no)
            text_iter = page.extractText().strip()
            ret += '\n' + text_iter.strip() 
    return ret.strip()

text = text_from_pdf_text(file_path)
print(text)
# Out:
# PdfReadWarning: Superfluous whitespace found in object header b'1' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'2' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'3' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'47' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'50' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'53' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'45' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'48' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'51' b'0' [pdf.py:1666]
# PdfReadWarning: Superfluous whitespace found in object header b'94' b'0' [pdf.py:1666]

# %%
file_path = r'C:\temp\temp\zip\82 Johtoryhmän esityslista\Johtoryhmä - Steering committee\2018-06-18\Emma-Maija johtoryhmän kokous 2018-06-18.pdf'

def text_from_pdf_image(file_path):
    pages = convert_from_path(file_path, 500)
    ret = ''
    for page in pages:
        ret += '\n' + pytesseract.image_to_string(page, lang="fin")
    return ret

text = text_from_pdf_image(file_path)
print(text)
# Out:
# Mari Laihiainen
#
# IKST= Tol olkolisteimlaak=lar=toista
# Tieto
# Mari.laihiainenOtieto.com
# Hankkeen yleistilanne
#
# PI4 toteutettu kaikki toiminnallisuudet lukuun ottamatta UC045 Maksukiellot (S-koko) (Vaatimukset muuttuivat 19.4.2018
# pidetyn arkkitehtuuripalaverin jälkeen useita kertoja määrittelytyöpajoissa).
#
# Yleiset havainnot ja tilanne
#
# Laatu Asiakkaan testausvastaavien kanssa käyty läpi PI4:ssa olevaa
# maksun laskennan testausta 30.5.2018, 15.6.2018, tällä
# pyritään varmistamaan releasetestauksen onnistuminen
# kesän aikana
# Versiosaatetta pyritty selkeyttämään ja tarkentamaan, jotta
# inkrementin sisältö on yksiselitteinen.
#
# Työmäärä ja
#
# kustannukset *
#
# VU
# f Asiakkaalle esitetty uudet työmääräarviot 14.5. hankkeen
# osalta.
#
# Toimenpiteet
# PIS esisuunnittelu käynnistynyt, jolla pyritään varmistamaan parempi PIS
# suunnittelutapahtuma 25. — 26.6.
#
# PIS suunnittelun jälkeen toteutussuunnitelma, jonka asiakas hyväksyy
# inkementin lähtökohdaksi
#
# Kokonaisuuden hallinta, tiedetään mitä pitää tehdä, jotta
# toiminnallisuudet saadaan tehtyä inkrementeissä
#
# Jatkuva parantaminen, työtapojen tehostaminen, tehdään oikeita asioita
#
# Tarkka inkrementtien suunnittelu ja seuranta
#
# Pyritään määrittelemään toiminnallisuudet niin, ettei niihin kohdistu
# merkittäviä muutoksia enää inkrementin aikana
#
# Tarkka muutoshallinta ja mahdollisten muutostarpeiden suunnittelu
# hyvissä ajoin, priorisointi ja uudelleen aikataulutus
# Resursointi road map suunnittelun pohjana
#
# Lisää toteuttajia, joilla varmistetaan aikataulu pito
#
# *Alkuperäiseen sopimukseen verrattuna hanke on kustannusten ja työmäärien osalta "punainen"
#
# Aikataulu Toimitus1 valmistuu hankkeen suunnittelemassa
# aikataulussa.
# Mahdolliset muutospyynnöt vaikuttavat hankkeen
# kokonaisaikatauluun
# Resursointi Uusia määrittelijöitä, toteuttajia ja testaajia hankkeeseen,
# jotta inkrementit toteutuvat suunnitellusti.
# O Tieto Corporation
#
# (O) Riski, Vaatii eriyistoimenpiteitä
#
# Jäljessä, mutta toimenpiteet tehoavat
#
# () Ei vaadi toimenpiteitä
#
# Confidential
#
# tieto
# Laskutuskertymä 1.5.2018- 31.5.2018
#
# Tavoitehinta €
#
#
#
# Yhteinen osuus 1
#
# Kevan as.koht. 1
# Varman as.koht. 1
# Kevan konversio
# Varman konversio
#
# Muut kulut (Keva)
# (sis. Muutospyynnöt)
#
# Muut kulut (Varma)
# (sis. Muutospyynnöt)
#
# Tukitehtävien osuus
#
# *
#
# Hallinnollisen työn
# osuus **
#
# 3 O Tieto Corporation
#
# 2 434 102
#
# 270 185
#
# 202 085
#
# 392 803
#
# 245 775
#
# Toteutunut
# ER UKKI
# 1.5. - 31.5.
#
#
#
# Laskutus-
# kertymä päivinä
#
# ERIN KEKYKS
#
# Laskutus-
# kertymä
# päivinä
# kumulat. (a
# '11))
#
# Laskutus-
# kertymä €
# (alv 0) ***
# 1.5. - 31.5.
# 4 924
# 121
# 87
# 542
#
# 536
#
# 13.40%
#
# 10.9%
#
# Laskutus-
# TALK: KS
# kumulat.
# (alv 0) ***
#
# 2876 443
# 91 032
# 65 378
#
# 354 194
# 366 148
#
# 2385
#
# 690
#
# Confidential
#
# Huom!
#
# * — Taulukossa ei ole huomioitu
# muutospyyntöjä.
# Laskutuskertymä sisältää ko
# kaudella laskutetun työn sekä
# ennustetun laskutuksen (tehty
# laskutettava työ, jota ei vielä
# ole laskutettu)
#
# * Tukityö sisältää
# arkkitehtuurityön,
# määrittelyvastaavan,
# testausvastaavan,
# testidatavastaavan,
# testiautomaatiovastaavan,
# release managerin,
# tietoturvakoordinaattorin ja
# Proxy PO:n työn. Se on
# laskettu laskutuskertymän
# tunneista.
#
# ** Hallinnollinen työ sisältää
# hankepäällikkö-, pää-scrum
# master- (RTE) ja scrum
# master -työn. Se on laskettu
# laskutuskertymän tunneista.
#
# *** Takuuvaraus (5%) sisältyy
#
# laskutuskertymään, mutta ei
# toteutuneeseen laskutukseen
#
# tieto
# Laskutuskertymä projekteittain
#
# 4000000
# 3500000
# 3000000
# 2500000
# 2000000
# 1500000
# 1000000
#
# 500000
#
# 0
#
# 400000
# 350000
# 300000
# 250000
# 200000
# 150000
# 100000
#
# 50000
#
# o
#
# 4
#
# Laskutuskertymä - Yhteinen osuus 1
#
# elo.17 — syys.17 — loka.17 — marras.17 —joulu.17 —tammi.18 — helmi.18 — maalis.18 — huhti.18 — touko.18
#
# Laskutuskertymä - Varman asiakaskohtainen osuus 1
#
# 150000
#
# 100000
#
# 50000 |
# N  -NHN
#
# elo.17 —syys.17 loka.17 marras.17 joulu.17 tammi.18 helmi.18 maalis. 18 huhti.18 touko.18 elo.17 —syys.17 |oka.17 marras.17 joulu.17 tammi.18 helmi.18 maalis.18 huhti.18 touko.18
# muun Laskutettu työ muun Laskutetut muutospyynnöt
# O Tieto Corporation mu Ennustettu laskutus = Tavoitehinta (viimeisin)
#
#
#
# Laskutuskertymä - Kevan asiakaskohtainen osuus 1
#
# 450000
# 400000
# 350000
# 300000
# 250000
# 200000
# 150000
# 100000
#
# s HälI
# > -s s t1öT8WN
#
# elo.17 syys.17 loka.17 marras.17joulu.17tammi.18helmi.18maalis.18huhti.18 touko.18
#
# Laskutuskertymä (Varman konversio)
#
# 400000
# 350000
# 300000
# 250000
#
# 200000
#
# = lavoitehinta + kynnys 1
#
#
#
# == 1avoitehinta + kynnys 2
#
# Laskutuskertymä - Kevan konversio
#
# 700000
# 600000
# 500000
# 400000
#
# 300000
#
# Confidential
#
# 200000
# 100000 || N f I
# m &&i W
#
# elo.17 syys.17 loka.17marras.1joulu.1ammi.18helmi.18maalis.18huhti.18touko.18
#
# Huom! Hyväksytyt, mutta
#
# laskuttamattomat muutospyynnöt eivät
#
# sisälly ennustettuun laskutukseen.
#
# tieto
# Riskianalyysi suurimmista riskeistä
#
# onfidential
#
#
#
#
# Riski Vaikutus — Todennäköisyys — Toimenpide riskin pienentämiseksi
#
#
#
#
# 6 Aiemmissa iteraatioissa Suuri Muodostetaan yhteinen käsitys vaatimuksista määrittelyn
# jatkotyön pohjaksi hyväksyttyjä yhteydessä, tiivis kommunikointi määrittelyn ja toteutuksen välillä.
# osia muutetaan merkittävästi Kuvataan kokonaisprosesseja, lisäksi kirjoitetaan vaatimukset
#
# tavalla, jotka tukevat paremmin järjestelmäkehitystä (user stories)
#
# 9 Suunniteltuja asioita ei saada Suuri Suuri e lisäresurssit ja resurssitilanteen aktiivinen seuranta.
# valmiiksi inkrementeissä * Road mapin seuranta sekä tiimien toteutumisen seuranta
#
# (päivä/viikkotasolla)
#
# 21 Ylioptimistinen työmääräarvio Suuri Suuri e Työmäärien arviointi kvartaaleittain, erikseen suunniteltavat
#
# tarjousvaiheessa toimenpiteet
# e Inkrementtien suunnittelu ja seuranta, toteutetaan arvoa tuottavia
# asioita kustannustehokkaasti
#
# 22 Tiedon kulku määrittelyn ja Suuri Suuri e Yhteistyötä parannettu Tsekin ja Suomen tekijöiden välillä.
# toteutuksen välillä Tiimissä määrittelijät ja toteuttajat päivittäin tekemisessä,
#
# Tsekeistä henkilöitä Suomessa työskentelemässä 2.- 4.5.
#
# =
# O Tieto Corporation O Riskitoteutunut O — Jäljessä, mutta toimenpiteet tehoavat = O Eivaaditoimenpiteitä tieto
# Hankejohdon — ja Johtoryhmän päätökset
#
# Johtoryhmältä vaadittavattavat päätökset
#
# Confidential
#
#
#
# Hanketason päätökset
#
# tieto
#
# O Tieto Corporation
# Muut asiat
#
# Confidential
#
# e l[omas Marton, nykyinen Tiedon työntekijä ja hankkeessa
# mukana oleva aloittaa 1.7.2018 toiminimellä
#
# e Juha Siltanen aloittaa 25.6.2018 Java Leadina Tiedon
# alihankkijana Ework Group Finland Oy
#
# e Joulukuun johtoryhmän siirto 18.12. ->17.12.
# e Earned Value työn alla
#
# 7 O Tieto Corporation tieto
# Seuraavat kokoukset
#
# e Heinäkuussa ei pidetä kokousta
# e 20.8.2018, klo 8:30 - 10:00
#
# e 18.9.2018, klo 9:00 - 10:30
#
# e 23.10.2018 klo 9:00 - 10:30
#
# e 20.11.2018 klo 9:00 - 10:30
#
# e 18.12.2018 klo 9:00 — 10:30
#
# 8 O Tieto Corporation
#
# Confidential
#
# tieto
# Inkrementin eteneminen
#
# Confidential
#
# Road map kokonaisuus Inkrementit
#
# 50
#
# 45
#
# 35
# 30
# 25
# 20
# |
# | Ji 1
# PI3 PI4 PIS Pl6 PI7 PI8 PI9
#
# W Suunniteltu m Toteutettu WMHTestauksessa MValmis MEitoteutettu
#
# >
#
# —
# oO
#
# n
#
# PI10
#
# 9 O Tieto Corporation tieto

# %%
def text_from_pdf(file_path):
    ret = text_from_pdf_text(file_path)
    if ret != '':
        return ret
    else:
        return text_from_pdf_image(file_path)

# %%
file_path = extension_files['pptx'][12]

def text_from_pptx(file_path):
    ret = ''
    prs = Presentation(file_path)
    for slide in prs.slides:
        for shape in slide.shapes:
            if hasattr(shape, "text"):
                ret += '\n' + shape.text
    return ret

text = text_from_pptx(file_path)
print(text)

# %%
file_path = extension_files['docx'][9]

def text_from_docx(file_path):
    return docx2txt.process(file_path)

# print(file_path)
text = text_from_docx(file_path)
print(text)
# Out:
# C:\temp\temp\zip\82 Johtoryhmän esityslista\Johtoryhmä - Steering committee\2019-04-26\Emma-Maija johtoryhmä 2019-03-26.docx
# Pöytäkirja
#
#
#
# ZIF Financial Services
#
#
#
# Tanja Scherf
#
#
#
#
#
#
#
# V1.0
#
# Luottamuksellinen
#
# 26.4.2019
#
#
#
#
#
# Emma-Maija johtoryhmä
#
# Aika
#
# 26.3.2019 klo 12:00 - 13.30
#
# Paikka
#
# Keva, 418 Empatia
#
# Läsnä
#
# Tom Kåla, Keva
#
# Anne Ruuskanen, Keva
#
# Anneli Kajas-Pätäri, Keva
#
# Panu Rautala, Keva
#
# Tiina Kurki, Varma
#
# 	Voppe Salokari, Varma
#
# Tiina Nykänen, Varma
#
# Minna Mattila, Varma
#
# Anne Heikkinen, Tieto
#
# Anja Ojala, Tieto
#
# Maarit Selin, Tieto
#
# Tanja Scherf, Tieto
#
# Puheenjohtaja
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sihteeri
#
#
#
#
#
#
#
# Poissa
#
# Mari Laihiainen, Tieto
#
#
#
#
#
# Kokouksen avaus
#
# Puheenjohtaja avasi kokouksen klo 12.00.
#
# Pöytäkirjan hyväksyminen ja avoimet tehtävät
#
# 	Hyväksyttiin edellisen kokouksen (12.2.2019) pöytäkirja.
#
# Tilanneraportti
#
# Tanja Scherf esitteli tilanneraportin.
#
# Hankkeen yleistilanteen osalta keskusteltiin, että tavoitteena on toimittaa PI8 inkrementti Asiakkaiden release testaukseen olemassa olevan aikataulun mukaisesti perjantaina 29.3.2019 vaikkakin toimittaja totesi testauksen olevan vielä kesken. Asiakkaiden release -testaus alkaa 1.4.2019.  PI8:n osalta keskusteltiin myös, että kaikki PI7 -leftover työt on sisällytetty PI8 inkrementtiin.
#
# Laadun osalta todettiin, että värikoodauksessa laadun väriä ei muuteta ennen kuin on nähty testauksen tulokset PI8:sta.
#
# Työmäärien ja kustannusten osalta keskusteltiin, että Tieto valmistelee huhtikuun ohjausryhmään, jo aiemmin sovitun mukaisesti, loppuprojektin tarkennetun aikataulun ja työmäärät. Aikatauluissa ja työmäärissä huomioidaan jäljellä olevat 1A:n työt, 1B:n työt sekä funnelissa olevat työt, jotka ovat testauksen ja määrittelyjen havaintoja sekä tarkennustarpeita eheyden varmistamiseksi.
#
# 1A:n töitä on priorisoitu 1B:hen aikatauluriskin pienentämiseksi. Asiakas totesi, että tällä hetkellä näyttää, että kaikki mahdolliset isot kokonaisuudet on jo siirretty ja siirtojen kautta ei enää ole mahdollista löytää ratkaisua aikatauluriskiin. Tiedon mielestä olisi edelleen mahdollista löytää 1B:hen siirrettäviä asioita. Priorisointia käydään vielä aktiivisesti läpi tuotehallinnassa yhteistyössä kaikkien osapuolten kanssa.
#
# Tieto kertoi, että määrittelyjen päättymispäivä on edelleenkin 31.5.2019. 1A:n määrittelyt valmistuvat pääosion iteraation 22 aikana, mutta pienempiä avoimia asioita on vielä yhteistyössä Asiakkaan kanssa käytävä läpi ja sovittava. Iteraatioissa 23 ja 24 tehdään 1B -määrittelyjä ja viimeistellään 1B -määrittelyjen rinnalla 1A -määrittelyt.
#
# Aikatauluriski on merkittävä, mutta todettiin, että edelleen on tavoite päästä maaliin aikataulussa. Asiakas nosti esille, että on todella tärkeää tietää riittävän ajoissa, mikäli aikataulu viivästyy.
#
# Varmistaakseen määrittelyjen etenemistä on Tiedon sisällä pyritty mahdollisimman hyvin turvaamaan määrittelijöiden työrauha. Seuraavissa inkrementeissä tarkennetaan tiimien vastuualueiden kohdentamista uudelleen osa-alueittain tehokkuuden ja selkeyden kasvattamiseksi.
#
# Funnel -työt eivät vielä ole EVA:ssa. Ne  käydään yksitellen läpi yhteistyössä Asiakkaan kanssa ja  ovat jatkossa mukana työmääräarvioissa. PI9 näyttää jo nyt  liian isolta vaikka  siihen ei vielä oltu huomioitu PI8:sta siirtyviä tehtäviä. Näissä siirtyvissä tehtävissä on vielä PI8:n aikana avoimeksi jääneitä, ilman lopullista ratkaisua olevia asioita. Huhtikuun johtoryhmässä esitettävässä suunnitelmassa huomioidaan PI9:n tilanne ja mahdollisuus siirtää tehtäviä PI10:een.
#
# Inkrementti PI8:n käsittelyn yhteydessä sovittiin, että jatkossa leftover / siirtyvät toiminnallisuudet -taulukkoon lisätään mukaan t-paita kokoluokan mukainen arvio ( S,M, L,XL). Leftover -taulukkoa hyödynnetään hankepäälliköiden yhteistyössä, kun esim. mietitään, onko inkrementistä toimitettu hyväksytysti kaikki toiminallisuudet vai pidätetäänkö laskutuksesta joku osa toiminnallisuuksista.
#
# Konversioiden osalta Asiakas totesi, että tilanne näyttää hyvältä. Tiedon puolella on tilanteesta sama käsitys. Asiakas nosti esille, että konversion luovutuksen osalta on tärkeä dokumentoida hyvin selkeästi, mitä luovutetaan, jotta toisen luovutuksen yhteydessä vältytään turhilta keskusteluilta virheistä ja niihin liittyvistä kustannuksista. Toista konversion luovutuspäivää ei vielä ole sovittu.
#
# Johtoryhmän materiaalissa esitetty ylätason kokonaiskuva koettiin hyväksi. Asiakas totesi ja oli samaa mieltä Tiedon kanssa, että kuvassa esitetyllä ylätasolla kaikkien alueiden määrittelyä on aloitettu.
#
# Kokonaiskuvaan toivottiin lisäyksenä omaa väriä valmistuneille kokonaisuuksille.
#
# Johtoryhmämateriaalissa ollut aikataulu -kuva todettiin myös tärkeäksi ja se päivitetään vastaamaan huhtikuussa annettavaa aikatauluarviota. Kuvaan lisätään mukaan Toimituksen 2 määrittelyjen ajankohta.
#
# Hankkeen johtoryhmälle päätettäväksi nostettavia asioita ei ollut.
#
# Riskit
#
# Riskilista käydään seuraavaan johtoryhmään tarkalla tasolla läpi ja päivitetään. Asiakas nosti esille, että onko tarve nostaa ’sovelluksessa paljon virheitä’ -riskiä  ja arvioida uudelleen riskiä  ”määrittelyn kokonaisuus ei ole ehyt”. Tilanne arvioidaan hankepäällikköpalaverissa.
#
# Aikatauluriski on edelleen suuri ja siihen on yritettävä edelleen löytää toimenpiteitä, joilla riski saadaan eliminoitua.
#
# Muut asiat
#
# Ylläpitosopimuksen neuvotteluiden käynnistämisestä Asiakas totesi, että jatketaan keskusteluja myöhemmin. Asiakas haluaa ensin nähdä Toimituksen 1 aikataulun ja etenemisen.
#
# Keva:lle on tärkeää saada ensin sopimus Toimituksesta 2.
#
# Tieto nosti esille, että rinnakkaiskäytön aikana vuoden 2020 –vaihteessa projektin aikainen ylläpito-organisaatio tarvitaan ja sen pystyttäminen ja projektin siirto ylläpitoon on suunniteltava huolellisesti ja etukäteen, jotta siirto kehityksestä ylläpitoon on joustava.
#
# Iloisena positiivisena asiana kerrottiin, että Tiedon Ilpo Paju on voittanut Vuoden testaaja 2018 palkinnon. Voittajan on valinnut julkiseen äänestykseen perustuenTestausOSY (testauksen osaamisyhteisö) ja Tieturi.
#
# Muutosloki
#
# Ei käsitelty tässä johtoryhmässä.
#
# Auditointitoimenpiteet
#
# Auditoinnin havaintojen yhteydessä todettiin, että esityksen nimi muutetaan jatkossa olemaan auditoinnin kehityshavainnot. Havaintojen osalta todettiin, että auditointiraporttien toimenpiteistä on kehitettävät kohdat valittu yhteistyössä Asiakkaan kanssa. Asiakkaalta nousi kysymyksenä teknisessä auditoinnissa olleen toimenpide-ehdotuksen tilanne maksuunlaskennan monoliittiä koskien. Lopputulos selvityksestä ja vaikutuksista esitetään huhtikuun johtoryhmässä.
#
# Testausraportti
#
# Testauksen statusraportti 25.3.2019 -tilanteesta käytiin läpi johtoryhmässä. Käsittelyn yhteydessä Asiakas nosti esille ison huolen testauksen etenemisestä riittävällä nopeudella, jotta aikataulun mukainen release -testaus voisi alkaa ajallaan.
#
# Testausraportin läpikäynnin yhteydessä todettiin, että huhtikuussa esitettävässä aikataulu- ja työmääräarviossa huomioidaan myös testaushavaintojen jäljellä olevat työmäärät.
#
# Seuraava kokous
#
# Vuoden 2019 johtoryhmän kokoukset:
#
# 17.04.2019 klo 11:30 – 13:00
#
# 22.05.2019 klo 09:00 – 10:30
#
# 20.06.2019 klo 13:00 – 14:30
#
# 20.08.2019 klo 09:00 – 10:30
#
# 24.09.2019 klo 10:00 – 11:30
#
# 24.10.2019 klo 10:00 – 11:30
#
# 29.11.2019  klo 10:00 – 11:30
#
# 17.12.2019  klo 10:00 – 11:30
#
# Kokouksen päättäminen
#
# Puheenjohtaja päätti kokouksen klo 13.27
#
# Liitteet
#
#
#
# Emma-Maija johtoryhmä 2019-2-12 hyväksytty pöytäkirja
#
# Kokousmateriaali
#
#
#
# Jakelu
#
# kokouksen osallistujat
#
# Tiedoksi
#
#
#
# Sovitut toimenpiteet
#
#
#
# Nro
#
# Toimenpide
#
# Vastuu
#
# Deadline
#
# Tila
#
# 50
#
# Auditoinnin havaintojen yhteydessä todettiin, että esityksen nimi muutetaan jatkossa olemaan auditoinnin kehityshavainnot
#
# Mari
#
# 26.4.
#
# Kesken
#
# 49
#
# Tuotehallinnan kokonaiskuvaan toivottiin lisäyksenä omaa väriä valmistuneille kokonaisuuksille
#
# Mari
#
#
#
# Kesken
#
# 48
#
# Aikataulukuvaan lisätään Toimituksen 2 määrittelyjen ajankohta
#
# Mari
#
# 26.4.
#
# Kesken
#
# 47
#
# Inkrementti PI8:n käsittelyn yhteydessä sovittiin, että jatkossa leftover / siirtyvät toiminnallisuudet -taulukkoon lisätään mukaan t-paita kokoluokan mukainen arvio ( S,M, L,XL).
#
# Tieto
#
# 26.4.
#
# Kesken
#
# 46
#
# Huhtikuun johtoryhmään valmistellaan aikataulu ja jäljellä oleva työmäärä  ja huomioidaan PI9:n tilanne ja mahdollisuus siirtää tehtäviä PI10:een.
#
#
#
# Mari
#
# 26.4
#
# Kesken
#
# 45
#
# Hankepäällliköt valmistelevat Toimituksen 1A osa 2 aikataulua sopimuksen aikataululiitteeseen
#
# PM
#
# 26.3.
#
# Ei tarvetta
#
# 44
#
# Johtoryhmän kokoukseen lisätään kokonaiskuva, joka kertoo hankkeen tilanteesta.
#
# Mari
#
# 26.3.
#
# Valmis
#
# 43
#
# Johtoryhmän esitykseen lisätään jatkossa kuva aikataulusta
#
# Mari
#
# 26.3.
#
# Valmis
#
# 42
#
# Muutospyyntöjen läpikäynti ja esitys johtoryhmälle
#
# PM
#
#
#
# Jatkuva
#
# 41
#
# Hankepäälliköt jatkavat auditointitulosten läpikäyntiä erilliseltä toimenpidelistalta
#
# PM
#
#
#
# Jatkuva
#
#
#
#
#
# Tehdyt päätökset
#
#
#
# Nro
#
# Päätös
#
# Pvm
#
# 25
#
# Toimituksesta 1A siirretään seuraavat toiminnallisuudet Toimitukseen 1B (Muutoslokin nrot 20 ja 21).
#
#
#
# Nro 20) Varma: Sosiaalilautakunnalle maksun siirtopäätös (maksussa olevalle eläkkeelle) Tulosteen Steve rajapinta -> 1B
#
# Nro 21) Varma: Ulkom. asuvan henkilön osoite muuttuu ja ulkom. tili->  manuaalitoiminnoksi, nostetaan tehtävä (Lähetä muuttunut osoite pankkiin). Siirretään 1B.
#
# 17.12.2018
#
#
#
#
#
#
#
# Arkistoidut toimenpiteet ja päätökset -linkki
#
#
#
#
#
# ______________
#
# Sivu 1/6
#
#
#
#
#
#
#
# emma-maija johtoryhmä 2019-03-26.docx

# %%
file_name
# Out:
# 'C:\\temp\\temp\\zip\\82 Johtoryhmän esityslista\\Johtoryhmä - Steering committee\\2019-08-22\\Emma-Maija johtoryhma¨n tilanneraportti 2019-08-22.pptx'

# %%
# !dir c:\temp\temp\text
# Out:
#  Volume in drive C is OSDisk
#  Volume Serial Number is 0802-D245
#
#  Directory of c:\temp\temp\text
#
# 21.12.2020  16.18    <DIR>          .
# 21.12.2020  16.18    <DIR>          ..
# 21.12.2020  16.17               906 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2017_05_29_Emma_Maija_johtoryhm„_2017_05_29_esityslista_pdf
# 21.12.2020  16.17             5ÿ203 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2017_05_29_Emma_Maija_johtoryhm„_2017_05_29_p”yt„kirja_pdf
# 21.12.2020  16.17             4ÿ026 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2017_05_29_Emma_Maija_johtoryhm„_2017_05_29_tilanneraportti_pdf
# 21.12.2020  16.17             9ÿ382 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2017_08_22_Emma_Maija_johtoryhm„n_kokous_2017_08_22_pdf
# 21.12.2020  16.17             8ÿ402 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2017_08_22_Emma_Maija_johtoryhm„_2017_08_22_p”yt„kirja_pdf
# 21.12.2020  16.17            11ÿ208 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2017_09_12_Emma_Maija_johtoryhm„n_kokous_2017_09_12_pdf
# 21.12.2020  16.17             8ÿ362 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2017
C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2018_02_12_Emma_Maija_johtoryhm„_2018_02_12_p”yt„kirja_pdf
# 21.12.2020  16.17            21ÿ568 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2018_02_12_Lliite_4_2_Riskilista_v_1_3_2017_02_12_pdf
# 21.12.2020  16.17             9ÿ793 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2018_03_19_Emma_Maija_johtoryhm„n_kokous_2018_03_19_pdf
# 21.12.2020  16.17             9ÿ980 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2018_03_19_Emma_Maija_johtoryhm„_2018_02_12_p”yt„kirja_v_1_1_pdf
# 21.12.2020  16.17             6ÿ781 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2018_03_19_Emma_Maija_johtoryhm„_2018_03_19_p”yt„kirja_v1_pdf
# 21.12.2020  16.17             9ÿ294 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2018_03_19_Lliite_4_2_Riskilista_v_1_3_2018_03_13_pdf
# 21.12.2020  16.18            10ÿ991 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2018_04_17_Emma_Maija_johtoryhmÇÏn_kokous_2018_04_17_pdf
# 21.12.2020  16.18             6ÿ781 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2018_04_17_Emma_Maija_johtoryhm„_2018_03_19_p”yt„kirja_v1_pdf
# 21.12.2020  16.18                 0 C__temp_temp_zip_82_Johtoryhm„n_esityslista_Johtoryhm„___Steering_committee_2018_04_17_Emma_Maija_johtoryhm„_2018_04_17_p”yt„kirja_v1_1_pdf
#               40 File(s)        396ÿ454 bytes
#                2 Dir(s)  200ÿ656ÿ900ÿ096 bytes free

# %%
for root, dirs, files in os.walk(root_dir, topdown=False):
    for name in files:
        file_path = os.path.join(root, name)
        if as_text_file_path(file_path) in os.listdir('C:/temp/temp/text'):
            print('passed')
            continue
        if name.endswith('pdf'):
            text = text_from_pdf(file_path)
        elif name.endswith('docx'):
            text = text_from_docx(file_path)
        elif name.endswith('pptx'):
            text = text_from_pptx(file_path)
        else:
            continue
        with open(as_text_file_path(file_path), 'w', errors = 'ignore') as f:
            f.write(text)
        print(name, len(text))
# Out:
# Emma-Maija johtoryhmä 2017-05-29 esityslista.pdf 832
# Emma-Maija johtoryhmä 2017-05-29 pöytäkirja.pdf 4757
# Emma-Maija johtoryhmä 2017-05-29 tilanneraportti.pdf 3778
# Emma-Maija johtoryhmä 2017-08-22 pöytäkirja.pdf 7672
# Emma-Maija johtoryhmän kokous 2017-08-22.pdf 8613
# Emma-Maija johtoryhmä 2017-08-22 pöytäkirja.pdf 7637
# Emma-Maija johtoryhmä 2017-09-12 pöytäkirja.pdf 7157
# Emma-Maija johtoryhmän kokous 2017-09-12.pdf 10333
# Emma-Maija johtoryhmä 2017-08-22 pöytäkirja.pdf 7637
# Emma-Maija johtoryhmä 2017-09-12 pöytäkirja.pdf 7157
# Emma-Maija johtoryhmä 2017-10-11 pöytäkirja.pdf 7793
# Emma-Maija johtoryhmän kokous 2017-10-11.pdf 18752
# Lliite 4.2 Riskilista v 1.1 2017-10-11.pdf 18997
# Emma-Maija johtoryhmä 2017-09-12 pöytäkirja.pdf 7157
# Emma-Maija johtoryhmä 2017-10-11 pöytäkirja.pdf 7793
# Emma-Maija johtoryhmä 2017-11-07 pöytäkirja.pdf 11802
# Emma-Maija johtoryhmän kokous 2017-11-07.pptx 4932
# Emma-Maija johtoryhmä 2017-10-11 pöytäkirja.pdf 7793
# Emma-Maija johtoryhmä 2017-11-07 pöytäkirja.pdf 11802
# Emma-Maija johtoryhmäraportti - 15.12.2020 draft.pptx 1665
# Emma-Maija johtoryhmä arkistoidut sovitut toimenpiteet ja päätökset.docx 11536

# %%
for text_file in os.listdir(text_dir):
    m = re.findall('20[0-9]+_[0-9]+_[0-9]+', text_file)
    if m == []:
        print(text_file)
    else:
        print(m)
# Out:
# ['2017_05_29', '2017_05_29']
# ['2017_05_29', '2017_05_29']
# ['2017_05_29', '2017_05_29']
# ['2017_08_22', '2017_08_22']
# ['2017_08_22', '2017_08_22']
# ['2017_09_12', '2017_09_12']
# ['2017_09_12', '2017_08_22']
# ['2017_09_12', '2017_09_12']
# ['2017_10_11', '2017_10_11']
# ['2017_10_11', '2017_08_22']
# ['2017_10_11', '2017_09_12']
# ['2017_10_11', '2017_10_11']
# ['2017_10_11', '2017_10_11']
# ['2017_11_07', '2017_11_07']
# ['2017_11_07', '2017_09_12']
# ['2017_11_07', '2017_10_11']
# ['2017_11_07', '2017_11_07']
# ['2017_12_12', '2017_12_12']
# ['2017_12_12', '2017_10_11']
# ['2017_12_12', '2017_11_07']
# ['2017_12_12', '2017_12_12']
# ['2017_12_12', '2017_12_12']
# ['2018_01_15']
# ['2018_01_15', '2018_01_15']
# ['2018_01_15', '2017_12_12']
# ['2018_01_15', '2018_01_15']
# ['2018_01_15', '2018_01_15']
# ['2018_01_15', '2017_12_12']
# ['2018_01_15', '2018_01_15']
# ['2018_02_12', '2018_02_12']
# ['2018_02_12', '2018_01_15']
# ['2018_02_12', '2018_02_12']
# ['2018_02_12', '2017_02_12']
# ['2018_03_19', '2018_03_19']
# ['2018_03_19', '2018_02_12']
# ['2018_03_19', '2018_03_19']
# ['2018_03_19', '2018_03_13']
# ['2018_04_17', '2018_04_17']
# ['2018_04_17', '2018_03_19']
# ['2018_04_17', '2018_04_17']
# ['2018_04_17', '2018_03_13']
# ['2018_05_14', '2018_05_14']
# ['2018_05_14', '2018_04_17']
# ['2018_05_14', '2018_05_14']
# ['2018_06_11']
# ['2018_06_11', '2018_05_14']
# ['2018_06_11']
# ['2018_06_18', '2018_06_18']
# ['2018_06_18', '2018_06_11']
# ['2018_06_18', '2018_06_18']
# ['2018_08_20', '2018_08_20']
# ['2018_08_20', '2018_06_18']
# ['2018_08_20', '2018_08_20']
# ['2018_08_20']
# ['2018_08_20']
# ['2018_08_20']
# ['2018_09_18', '2018_09_18']
# ['2018_09_18', '2018_08_20']
# ['2018_09_18', '2018_09_18']
# ['2018_10_26', '2018_10_26']
# ['2018_10_26', '2018_09_18']
# ['2018_10_26', '2018_10_26']
# ['2018_10_26', '2018_11_06']
# ['2018_10_26', '2018_10_24']
# ['2018_10_26']
# ['2018_10_26']
# ['2018_10_26']
# ['2018_10_26']
# ['2018_10_26']
# ['2018_11_20', '2018_11_19']
# ['2018_11_20', '2018_11_20']
# ['2018_11_20', '2018_10_26']
# ['2018_11_20', '2018_11_20']
# ['2018_11_20', '2019_11_20']
# ['2018_12_17', '2018_12_17']
# ['2018_12_17', '2018_11_20']
# ['2019_01_17', '2019_01_17']
# ['2019_01_17', '2018_12_17']
# ['2019_02_12', '2019_02_12']
    m = re.findall('20[0-9]+_[0-9]+_[0-9]+', text_file)
    if m == []:
        continue
    pvm = m[-1]
    text_file_path = os.path.join(text_dir, text_file)
    with open(text_file_path, 'r') as f:
        text = f.read()
    print(text_file.split('_')[-1], len(text))
    word_count = defaultdict(int)
    for word_raw in re.split('\W+', text):
        word = word_raw.lower().strip('-.,/%(!)*&+#"$\'')
        word_count[word.lower()] += 1
    df = pd.DataFrame(dict(word_count), index = ['lkm']).T.reset_index()
    df['pvm'] = pvm
    if df_total is None:
        df_total = df
    else:
        df_total = df_total.append(df)
ret = sorted(word_count.items(), key = lambda item: -1 * item[1])
# Out:
# pdf 832
# pdf 4757
# pdf 3778
# pdf 8613
# pdf 7672
# pdf 10333
# pdf 7637
# pdf 7157
# pdf 18752
# pdf 7637
# pdf 7157
# pdf 7793
# pdf 18997
# pptx 4932
# pdf 7157
# pdf 7793
# pdf 11802
# pdf 9497
# pdf 7793
# pdf 11802
# pdf 7110
# pdf 20145
# pdf 6737
# pdf 10675
# pdf 7110
# pdf 9604
# pdf 10225
# pdf 20145
# pdf 1371
# pdf 11316
# pdf 10225
# pdf 8783
# pdf 20138
# pdf 9162
# pdf 9042
# pdf 6550
# pdf 8885
# pdf 10377
# pdf 6550
# pdf 3413
# pdf 9203
# pdf 13732
# pdf 3413
# docx 4399
# pdf 1935
# pdf 4958
# pdf 1949
# pdf 5400
# pdf 6527
# docx 4673
# pdf 6308
# docx 4685
# docx 9994
# pdf 1713
# pptx 4020
# pptx 360
# pdf 6849
# docx 10004
# docx 6623
# pdf 8134
# pdf 6999
# pdf 11683
# pdf 3462
# pdf 1779
# pdf 16053
# pdf 16404
# pdf 12988
# pdf 3597
# pdf 3665
# pdf 2510
# pdf 4790
# pdf 10616
# docx 8801
# pdf 3730
# pdf 9098
# docx 8801
# pdf 5179
# pdf 9223
# pdf 14928
# pptx 5224
# pdf 10438
# docx 9262
# pdf 11166
# pptx 5314
# pdf 11166
# pptx 5740
# docx 9218
# pptx 3172
# pdf 11087
# pptx 3098
# pdf 6741
# pptx 5739
# docx 7482
# pdf 9186
# docx 13771
# pptx 3135
# pptx 2
# pptx 5230
# docx 9374
# pptx 7310
# docx 8294
# pdf 8982
# pptx 3026
# docx 8332
# pdf 9081
# pptx 2641
# docx 5722
# pptx 1907
# docx 4872
# docx 6265
# docx 6758
# docx 6713
# pptx 4340
# docx 8170
# pptx 6078
# docx 1454
# pptx 1541
# pptx 5386
# pptx 3216
# pptx 5217
# docx 10532
# docx 9829
# docx 9716
# pptx 3541
# pptx 4356
# docx 6207
# docx 2507
# pptx 4247
# pptx 2046
# docx 4293
# docx 4307
# pdf 6107
# pptx 4729
# pptx 2088
# pptx 2738
# pptx 2367
# docx 11922
# pptx 7962
# docx 8804
# pptx 2507
# docx 9456
# pptx 11690
# docx 15613
# pptx 4966
# pptx 2057
# pdf 1714
# pdf 46
# pptx 2303
# docx 10617
# pdf 46
# pptx 117
# pptx 3415
# docx 10602
# pdf 46
# pptx 3697
# pptx 3697
# docx 7956
# pptx 6416
# docx 7135
# pdf 46
# pptx 1665

# %%
df_total.columns = ['word', 'count', 'date']

# %%
df = df_total

# %%
df['year'] = df.date.str[:4]

# %%
kaikki_sanat = list(df.word.unique())

# %%
len(kaikki_sanat)
# Out:
# 12931

# %%
gr = df.groupby(['word'])['count'].count().to_frame()

# %%
sanat = list(gr.loc[gr['count'] > 2].index)

# %%
len(sanat)
kaikki_sanat = [s for s in sanat if len(s) > 2]
len(kaikki_sanat)
# Out:
# 4992

# %%
with open('C:/temp/temp/voikko/sanat', 'w', encoding = 'latin', errors = 'ignore') as f:
    f.write("\n".join(kaikki_sanat))

# %%
gr = df.groupby(['word', 'year'])['count'].count().unstack().reset_index()

# %%
gr.loc[gr.word.str.contains('toimittaja')]
# Out:
# year                 word  2017  2018  2019  2020
# 882          33toimittaja   NaN   1.0   NaN   NaN
# 5963   laitetoimittajalta   NaN   NaN   NaN   1.0
# 10960          toimittaja   5.0  14.0  13.0  32.0
# 10961         toimittajaa   NaN   NaN   NaN   3.0
# 10962       toimittajaksi   NaN   1.0   NaN   NaN
# 10963       toimittajalla   7.0   5.0   8.0  12.0
# 10964       toimittajalle  10.0   3.0   2.0   5.0
# 10965       toimittajalta   NaN   NaN   NaN   8.0
# 10966         toimittajan  13.0  15.0  16.0  46.0
# 10967        toimittajana   NaN   NaN   NaN   1.0
# 10968       toimittajasta   NaN   NaN   NaN   3.0

# %%
gr.loc[gr.word.str.contains('pi6')]
# Out:
# year                                  word  2017  2018  2019  2020
# 2668  confidentialkonversionvalmiusastepi6   NaN   1.0   NaN   NaN
# 2687                       confidentialpi6   NaN   1.0   NaN   NaN
# 8213                                   pi6   NaN  13.0   3.0   NaN
# 8214                                 pi675   NaN   1.0   NaN   NaN

# %%
import pandas as pd
# Out:
#               index  lkm
# 0      confidential  387
# 1              emma  650
# 2             maija  590
# 3       johtoryhmän  367
# 4            kokous  222
# ...             ...  ...
# 12928          2600    1
# 12929          5560    1
# 12930  tehtävälista    1
# 12931   arkistointi    1
# 12932  asialistalle    2
#
# [12933 rows x 2 columns]

# %%
character_count = defaultdict(int)

for r in ret:
    for c in r[0]:
        character_count[c] += 1

# %%
# ret
# ord('a'), ord('0')
# "".join([c for c in character_count.keys() if ord(c) < 48])
# [r for r in ret if len(r[0]) > 34]
# [r for r in ret if 'pi' in r[0].lower()]
# ret
len(ret)
# Out:
# 142

# %%
!"C:\Program Files\Tesseract-OCR\tesseract" --list-langs
# Out:
# List of available languages (3):
# eng
# fin
# osd

# %%
# import voikko
import libvoikko

# %%
voikko = voikko.init('fi')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-0aa9083941bd> in <module>
# ----> 1 voikko = voikko.init('fi')
#
# AttributeError: module 'voikko' has no attribute 'init'

# %%
voikko = libvoikko.Voikko(u"fi")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-113-eeaca660320d> in <module>
# ----> 1 voikko = libvoikko.Voikko(u"fi")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\libvoikko.py in __init__(self, language, path)
#     434            path      Extra path that will be checked first when looking for linguistic
#     435                      resources."""
# --> 436         self.__lib = self.__getLib()
#     437
#     438         error = c_char_p()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\libvoikko.py in __getLib(cls)
#     420     @classmethod
#     421     def __getLib(cls):
# --> 422         return VoikkoLibrary.open(path=cls._sharedLibrarySearchPath)
#     423
#     424     @classmethod
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\libvoikko.py in open(cls, path)
#     300                 except:
#     301                     pass
# --> 302         return cls(fileName)
#     303
#     304     def __init__(self, filename):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\libvoikko.py in __init__(self, filename)
#     303
#     304     def __init__(self, filename):
# --> 305         super(VoikkoLibrary, self).__init__(filename)
#     306
#     307         self.voikkoInit.argtypes = [POINTER(c_char_p), c_char_p, c_char_p]
#
# ~\AppData\Local\Continuum\anaconda3\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     362
#     363         if handle is None:
# --> 364             self._handle = _dlopen(self._name, mode)
#     365         else:
#     366             self._handle = handle
#
# OSError: [WinError 126] The specified module could not be found

# %%
import sys

# %%
sys.path
# Out:
# ['C:\\Users\\jokemjaa\\Google Drive\\python\\Jupyter\\notebooks\\Art',
#  'C:\\Users\\jokemjaa\\AppData\\Local\\Continuum\\anaconda3\\python37.zip',
#  'C:\\Users\\jokemjaa\\AppData\\Local\\Continuum\\anaconda3\\DLLs',
#  'C:\\Users\\jokemjaa\\AppData\\Local\\Continuum\\anaconda3\\lib',
#  'C:\\Users\\jokemjaa\\AppData\\Local\\Continuum\\anaconda3',
#  '',
#  'C:\\Users\\jokemjaa\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\jokemjaa\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\jokemjaa\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\jokemjaa\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\jokemjaa\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\jokemjaa\\.ipython']

# %% [markdown]
# ```
# root@bbaedc3dc663:/# history
#     1  sudo apt  install  voikko-fi python-libvoikko
#     2  apt  install  voikko-fi python-libvoikko
#     3  apt  install  -y voikko-fi -y python-libvoikko
#     4  apt-get  install  voikko-fi python-libvoikko
#     5  sudo apt-get install libreoffice-voikko tmispell-voikko libenchant-voikko
#     6  apt-get install libreoffice-voikko tmispell-voikko libenchant-voikko
#     7  apt-get install -y libreoffice-voikko tmispell-voikko libenchant-voikko
#     8  apt-get update
#     9  apt-get install libreoffice-voikko tmispell-voikko libenchant-voikko
#    10  python
#    11  apt install python3.7
#    12  apt install software-properties-common
#    13  add-apt-repository ppa:deadsnakes/ppa
#    14  apt install python3.7
#    15  python --version
#    16  python3.7 --version
#    17  python3.7
#    18  history
#    ```
#
#    - https://voikko.puimula.org/python.html
#    - https://antupis.github.io/lemmatization/finnish/2019/06/12/Lemmatizing-finnish-text.html
#    - https://www.puimula.org/htp/testing/js-libvoikko/js-libvoikko-demo.html#
#    - https://github.com/voikko/corevoikko/
#    - https://data.solita.fi/finnish-stemming-and-lemmatization-in-python/
#    - https://textract.readthedocs.io/en/stable/index.html
#    - https://github.com/UB-Mannheim/tesseract/wiki/Install-additional-language-and-script-models
#    - https://www.puimula.org/htp/doc/python/libvoikko.html
#
#    `docker run -v "c:\temp\temp\voikko":/voikko -it --name voikko -rm voikko`

# %%
https://www.puimula.org/htp/doc/python/libvoikko.html

# %%
# %%writefile c:/temp/temp/voikko/ping.py
print("Hello world")
# Out:
# Writing c:/temp/temp/voikko/ping.py

# %%
a = (1, 2)
a.append(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-b74d760b1c46> in <module>
#       1 a = (1, 2)
# ----> 2 a.append(2)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# %%writefile c:/temp/temp/voikko/sanat.py

with open('sanat', 'r', encoding = 'Latin') as f:
    sanat = f.read().split('\n')

# print(sanat)
import libvoikko
v = libvoikko.Voikko('fi')

def my_guess(sana):
    ret = '?'
    an = v.analyze(sana)
#     print(an)
    if an != []:
        ret = an[0]['BASEFORM']
        return ret
    else:
        su = v.suggest(sana)
        if su != []:
            return su[0]
    return ret

for sana in sanat:
    print(sana, my_guess(sana))
# Out:
# Overwriting c:/temp/temp/voikko/sanat.py
